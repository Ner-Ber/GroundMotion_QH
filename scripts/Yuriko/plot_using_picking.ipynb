# %%
import numpy as np
from obspy import UTCDateTime
import obspy as obs
from obspy.clients.fdsn import Client as FDSN_Client
import numpy as np
from matplotlib import pyplot as plt
import sys
from ground_motion_qh import extract_pairs
from ground_motion_qh.catalog import Catalog
from ground_motion_qh.earthquake import EarthquakeCatalog
# import earthquake import EarthquakeCatalog
from pathlib import Path
from ground_motion_qh.get_waveforms import get_stream_multiple_stations, raw_stream_to_amplitude_and_times

# %%
earquake_metadata = {
    "starttime": '2000-01-01',
    "endtime": '2023-01-01',
    "latitude_range": [33,34],
    "longitude_range": [-117,-116],
    "minimum_magnitude": 3.0, 
}

station_metadata = dict(
    stname = ["SND"],
    network = "AZ",
    org = "IRIS",
)

# %%
earthquakes = EarthquakeCatalog(
    filename="local_catalog.csv",
    kwargs=earquake_metadata,
)
# Out:
# /Users/kdascher/Documents/Documents/USU/Projects/Exploratory_projects/GroundMotion_QH/ground_motion_qh/earthquake.py:196: UserWarning: Reloading local_catalog.csv
#   warnings.warn(f"Reloading {filename}")

# %%
earthquakes.plot_time_series()
# Out:
# <Axes: xlabel='Time', ylabel='mag'>

# %%
event_time_window = 30 # seconds (also we refer to this as tw-)
buffer = 0
forecast_time_window = 60*60 # seconds (also we refer to this as tw+)

# %%
A_pre = []
A_post = []

for i, t0 in enumerate(earthquakes.catalog.time):
    print(f"Dowloading event {i}")
    
    try:
        stream_dict = get_stream_multiple_stations(
            t1=UTCDateTime(t0),
            t2=UTCDateTime(t0 + np.timedelta64(event_time_window, "s")),
        )
        a_trigger, _ = raw_stream_to_amplitude_and_times(stream_dict["SND"])

        stream_dict = get_stream_multiple_stations(
            t1=UTCDateTime(t0 + np.timedelta64(event_time_window + buffer, "s")),
            t2=UTCDateTime(t0 + np.timedelta64(event_time_window + buffer + forecast_time_window, "s")),
        )
        a_forecast, _ = raw_stream_to_amplitude_and_times(stream_dict["SND"])
        
        A_pre.append(a_trigger)
        A_post.append(a_forecast)
        
    except Exception as e:
        print(f"Error dowloading event {i}: {e}")
        A_pre.append(np.array([]))
        A_post.append(np.array([]))
        
        continue
# Out:
# Dowloading event 0
# Dowloading event 1
# Dowloading event 2
# Dowloading event 3
# Dowloading event 4
# Dowloading event 5
# Dowloading event 6
# Dowloading event 7
# Dowloading event 8
# Dowloading event 9
# Dowloading event 10
# Dowloading event 11
# Dowloading event 12
# Dowloading event 13
# Dowloading event 14
# Dowloading event 15
# Dowloading event 16
# Dowloading event 17
# Dowloading event 18
# Dowloading event 19
# Dowloading event 20
# Dowloading event 21
# Dowloading event 22
# Dowloading event 23
# Dowloading event 24
# Error dowloading event 24: operands could not be broadcast together with shapes (6665,) (12076,)
# Dowloading event 25
# Error dowloading event 25: operands could not be broadcast together with shapes (6105,) (225620,)
# Dowloading event 26
# Dowloading event 27
# Dowloading event 28
# Dowloading event 29
# Dowloading event 30
# Dowloading event 31
# Dowloading event 32
# Dowloading event 33
# Dowloading event 34
# Dowloading event 35
# Dowloading event 36
# Dowloading event 37
# Dowloading event 38
# Dowloading event 39
# Dowloading event 40
# Dowloading event 41
# Dowloading event 42
# Dowloading event 43
# Dowloading event 44
# Dowloading event 45
# Dowloading event 46
# Dowloading event 47
# Dowloading event 48
# Dowloading event 49
# Dowloading event 50
# Error dowloading event 50: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event
# Dowloading event 180
# Dowloading event 181
# Dowloading event 182
# Dowloading event 183
# Dowloading event 184
# Dowloading event 185
# Dowloading event 186
# Dowloading event 187
# Dowloading event 188
# Dowloading event 189
# Dowloading event 190
# Dowloading event 191
# Dowloading event 192
# Dowloading event 193
# Dowloading event 194
# Dowloading event 195
# Dowloading event 196
# Dowloading event 197
# Dowloading event 198
# Dowloading event 199
# Dowloading event 200
# Dowloading event 201
# Error dowloading event 201: Service responds: Internal server error
# HTTP Status code: 500
# Detailed response of server:
#
# Error 500: Error calling internal metadata service, code 500 [Server closed connection without sending any data back at /usr/share/perl5/vendor_perl/Net/HTTP/Methods.pm line 373.
# ]
# More Details:
# handler exited, code: 1  reason: Internal Server Error
# Request:
# http://service.iris.edu/fdsnws/dataselect/1/query?starttime=2013-02-21T20%3A57%3A38.230000&endtime=2013-02-21T20%3A58%3A08.230000&network=AZ&station=SND&location=%2A&channel=HHE
# Request Submitted:
# 2025/05/06 17:24:13 UTC
# Service version:
# Service: fdsnws-dataselect  version: 1.1.9
# Dowloading event 202
# Dowloading event 203
# Dowloading event 204
# Dowloading event 205
# Dowloading event 206
# Dowloading event 207
# Dowloading event 208
# Dowloading event 209
# Dowloading event 210
# Dowloading event 211
# Dowloading event 212
# Dowloading event 213
# Dowloading event 214
# Dowloading event 215
# Dowloading event 216
# Dowloading event 217
# Dowloading event 218
# Dowloading event 219
# Dowloading event 220
# Dowloading event 221
# Dowloading event 222
# Dowloading event 223
# Dowloading event 224
# Dowloading event 225
# Dowloading event 226
# Dowloading event 227
# Dowloading event 228
# Dowloading event 229
# Dowloading event 230
# Dowloading event 231
# Dowloading event 232
# Dowloading event 233
# Dowloading event 234
# Dowloading event 235
# Dowloading event 236
# Dowloading event 237
# Dowloading event 238
# Dowloading event 239
# Dowloading event 240
# Dowloading event 241
# Dowloading event 242
# Error dowloading event 242: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 243
# Dowloading event 244
# Dowloading event 245
# Dowloading event 246
# Dowloading event 247
# Dowloading event 248
# Dowloading event 249
# Dowloading event 250
# Dowloading event 251
# Dowloading event 252
# Dowloading event 253
# Dowloading event 254
# Dowloading event 255
# Dowloading event 256
# Dowloading event 257
# Dowloading event 258
# Dowloading event 259
# Dowloading event 260
# Dowloading event 261
# Dowloading event 262
# Dowloading event 263
# Dowloading event 264
# Dowloading event 265
# Dowloading event 266
# Dowloading event 267
# Dowloading event 268
# Dowloading event 269
# Dowloading event 270
# Dowloading event 271
# Dowloading event 272
# Dowloading event 273
# Dowloading event 274
# Dowloading event 275
# Dowloading event 276
# Dowloading event 277
# Dowloading event 278
# Dowloading event 279
# Dowloading event 280
# Dowloading event 281
# Dowloading event 282
# Dowloading event 283
# Dowloading event 284
# Dowloading event 285
# Dowloading event 286
# Dowloading event 287
# Dowloading event 288
# Dowloading event 289
# Dowloading event 290
# Dowloading event 291
# Dowloading event 292
# Dowloading event 293
# Dowloading event 294
# Dowloading event 295
# Dowloading event 296
# Dowloading event 297
# Dowloading event 298
# Dowloading event 299
# Dowloading event 300
# Dowloading event 301
# Dowloading event 302
# Dowloading event 303
# Dowloading event 304
# Dowloading event 305
# Dowloading event 306
# Dowloading event 307
# Dowloading event 308
# Dowloading event 309
# Dowloading event 310
# Dowloading event 311
# Dowloading event 312
# Dowloading event 313
# Dowloading event 314
# Dowloading event 315
# Dowloading event 316
# Dowloading event 317
# Dowloading event 318
# Dowloading event 319
# Dowloading event 320
# Dowloading event 321
# Dowloading event 322
# Error dowloading event 322: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 323
# Dowloading event 324
# Dowloading event 325
# Dowloading event 326
# Dowloading event 327
# Dowloading event 328
# Dowloading event 329
# Dowloading event 330
# Dowloading event 331
# Dowloading event 332
# Dowloading event 333
# Dowloading event 334
# Dowloading event 335
# Dowloading event 336
# Dowloading event 337
# Dowloading event 338
# Dowloading event 339
# Dowloading event 340
# Error dowloading event 340: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 341
# Error dowloading event 341: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 342
# Error dowloading event 342: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 343
# Error dowloading event 343: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 344
# Error dowloading event 344: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 345
# Error dowloading event 345: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 346
# Error dowloading event 346: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 347
# Dowloading event 348
# Dowloading event 349
# Dowloading event 350
# Dowloading event 351
# Dowloading event 352
# Dowloading event 353
# Dowloading event 354
# Dowloading event 355
# Dowloading event 356
# Dowloading event 357
# Dowloading event 358
# Error dowloading event 358: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 359
# Dowloading event 360
# Dowloading event 361
# Dowloading event 362
# Dowloading event 363
# Dowloading event 364
# Dowloading event 365
# Dowloading event 366
# Dowloading event 367
# Dowloading event 368
# Dowloading event 369
# Dowloading event 370
# Dowloading event 371
# Dowloading event 372
# Dowloading event 373
# Dowloading event 374
# Dowloading event 375
# Dowloading event 376
# Dowloading event 377
# Dowloading event 378
# Dowloading event 379
# Dowloading event 380
# Dowloading event 381
# Dowloading event 382
# Dowloading event 383
# Dowloading event 384
# Dowloading event 385
# Dowloading event 386
# Dowloading event 387
# Error dowloading event 387: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 388
# Error dowloading event 388: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 389
# Error dowloading event 389: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 390
# Dowloading event 391
# Dowloading event 392
# Dowloading event 393
# Dowloading event 394
# Dowloading event 395
# Dowloading event 396
# Dowloading event 397

# %%
a_forecast_max = np.array([np.max(np.abs(a-np.mean(a))) for a in A_post if np.any(a)])
a_trigger_max = np.array([np.max(np.abs(a-np.mean(a))) for a in A_pre if np.any(a)])

# %%
fig, ax = plt.subplots(2,1, sharex=True)
ax[0].scatter(a_trigger_max, a_forecast_max, s=1)
ax[0].set(
    ylabel="PGV in trigger interval",
    yscale="log",
)

ax[1].scatter(a_trigger_max, a_forecast_max/a_trigger_max, s=1)
ax[1].set(
    xlabel="PGV in trigger interval",
    ylabel="PGV+/PGV-",
    yscale="log",
    xscale="log",
)
ax[1].axhline(1, color="k", linestyle="--")

# %%
np.mean(a_forecast_max/a_trigger_max>1)
# Out:
# np.float64(0.05026455026455026)

# %%
# save a_forecast_max and a_trigger_max
np.save("a_forecast_max.npy", a_forecast_max)
np.save("a_trigger_max.npy", a_trigger_max)
