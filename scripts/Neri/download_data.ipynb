# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from obspy import UTCDateTime
from matplotlib import pyplot as plt
import ground_motion_qh
from ground_motion_qh.earthquake import EarthquakeCatalog
from ground_motion_qh.get_waveforms import get_stream_multiple_stations, raw_stream_to_amplitude_and_times
import os
from pathlib import Path
from pprint import pprint
import pickle
from obspy.taup import TauPyModel
model = TauPyModel(model="iasp91")

base_dir = Path(ground_motion_qh.__file__).parent.parent
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
download_name = "ANZA_SND_1994_M4_4hForecast"

# check if the folder already exists in the raw data folder
data_dir = base_dir / "data" / "raw_data" / download_name
if data_dir.exists():
    print(f"Folder {download_name} already exists in the raw data folder.")

# MAKE SURE TO CHANGE STATION LOCATION ALONG WITH THE STATION NAME!
station_metadata = dict(
    stname = ["SND"],
    network = "AZ",
    org = "IRIS",
    latitude = 33.5519,
    longitude = -116.6129,
    start_time = '1982-10-01',
    number_of_tries = 2,
)

earthquake_metadata = {
    "starttime": '1994-01-01',
    "endtime": '2023-01-01',
    "latitude_range": [32,35],
    "longitude_range": [-117.5,-115.5],
    "minimum_magnitude": 4.0, 
}

# explanation of buffers:

# (hypocenter) t1                                                                                            t2
# t0 time shift    pre-buffer     event time window     mid buffer     forecast time window      post buffer
# |------------||--------------||-------------------||--------------||---------- ... ---------||-------------|

analysis_metadata = dict(
    mid_buffer = 20,
    forecast_time_window = 4*60*60,
    event_time_window = 30,
    shift_times = True,
)

analysis_metadata["pre_buffer"] = 3*0.05 * analysis_metadata["forecast_time_window"] + analysis_metadata["event_time_window"] + analysis_metadata["mid_buffer"]
analysis_metadata["post_buffer"] = 3*0.05 * analysis_metadata["forecast_time_window"] + analysis_metadata["event_time_window"] + analysis_metadata["mid_buffer"]

# %%
pprint(analysis_metadata, width=1)
# Out:
# {'event_time_window': 30,
#  'forecast_time_window': 14400,
#  'mid_buffer': 20,
#  'post_buffer': 2210.0000000000005,
#  'pre_buffer': 2210.0000000000005,
#  'shift_times': True}

# %%
metadata = dict(
    earthquake_metadata = earthquake_metadata,
    analysis_metadata = analysis_metadata,
    station_metadata = station_metadata,
)
# create a data directory with and save the metadata
data_dir = base_dir / "data" / "raw_data" / download_name
os.makedirs(data_dir, exist_ok=True)
np.save(data_dir / "metadata.npy", metadata)

# to load the metadata
#metadata = np.load(data_dir / "metadata.npy", allow_pickle=True).item()

# %%
earthquakes = EarthquakeCatalog(
    filename=data_dir / "local_catalog.csv",
    kwargs=earthquake_metadata,
)
# Out:
# /home/neriberman/Repos/QuakeHack/GroundMotion_QH/ground_motion_qh/earthquake.py:196: UserWarning: Reloading /home/neriberman/Repos/QuakeHack/GroundMotion_QH/data/raw_data/ANZA_SND_1994_M4_4hForecast/local_catalog.csv
#   warnings.warn(f"Reloading {filename}")

# %%
earthquakes.plot_time_series()
# Out:
# <Axes: xlabel='Time', ylabel='mag'>

# %%
earthquakes.plot_map()
# Out:
# <GeoAxes: xlabel='Longitude', ylabel='Latitude'>

# %%
station_x, station_y, _, _ = earthquakes.get_utm_from_lonlat(station_metadata["longitude"], station_metadata["latitude"])
earthquakes_x, earthquakes_y, _, _ = earthquakes.get_utm_from_lonlat(earthquakes.catalog.lon.values, earthquakes.catalog.lat.values) 
distances = np.sqrt((earthquakes_x - station_x)**2 + (earthquakes_y - station_y)**2)

# %%
plt.hist(distances/1000)
plt.xlabel("Station-Earhthquake distance (km)")
# Out:
# Text(0.5, 0, 'Station-Earhthquake distance (km)')

# %%
minus_time_range = [
    analysis_metadata["pre_buffer"],
    analysis_metadata["pre_buffer"] + analysis_metadata["event_time_window"]
]

plus_time_range = [
    analysis_metadata["pre_buffer"] + analysis_metadata["event_time_window"],
    analysis_metadata["pre_buffer"] + analysis_metadata["event_time_window"] + analysis_metadata["mid_buffer"]
]

# %%
a_max_minus = []
a_max_plus = []

for i, (t0, distance, depth) in enumerate(zip(earthquakes.catalog.time, distances, earthquakes.catalog.depth)):
    print(f"Dowloading event {i}: {t0}")

    travel_time = distance/ 1000 / 5.7

    print(travel_time)

    # calculate the time of the event
    t1 = t0 + np.timedelta64(
        int(
            travel_time - analysis_metadata["pre_buffer"]
        ),  # (QUAKE) HACK
        "s",
    )

    t2 = t1 + np.timedelta64(
        int(  # (QUAKE) HACK
            analysis_metadata["pre_buffer"]
            + analysis_metadata["event_time_window"]
            + analysis_metadata["mid_buffer"]
            + analysis_metadata["forecast_time_window"]
            + analysis_metadata["post_buffer"]
        ),
        "s",
    )

    # preprocess the waveforms
    i = 0
    while i < station_metadata["number_of_tries"]:
        try:
            stream_dict = get_stream_multiple_stations(
                t1=UTCDateTime(t1),
                t2=UTCDateTime(t2),
            )

            event_dir = data_dir / f"data/{t1.strftime('%Y-%m-%d_%H-%M-%S')}"

            os.makedirs(event_dir, exist_ok=True)

            with open(event_dir / "stream_dict.pkl", "wb") as f:
                pickle.dump(stream_dict, f)

            amplitude, times = raw_stream_to_amplitude_and_times(stream_dict["SND"])
            np.save(event_dir / "amplitude.npy", amplitude)
            np.save(event_dir / "times.npy", times)

            minus_time_range = [
                analysis_metadata["pre_buffer"],
                analysis_metadata["pre_buffer"]
                + analysis_metadata["event_time_window"],
            ]

            plus_time_range = [
                analysis_metadata["pre_buffer"]
                + analysis_metadata["event_time_window"],
                analysis_metadata["pre_buffer"]
                + analysis_metadata["event_time_window"]
                + analysis_metadata["mid_buffer"],
            ]

            a_minus = amplitude[
                (times >= minus_time_range[0]) & (times <= minus_time_range[1])
            ]
            a_plus = amplitude[
                (times >= plus_time_range[0]) & (times <= plus_time_range[1])
            ]

            a_max_minus.append(
                np.max(a_minus)
            )  # note that the instrument response is removed, then we detrend, and hi
            a_max_plus.append(np.max(a_plus))

        except Exception as e:
            print(f"Error dowloading event {i}: {e}")

        i += 1
# Out:
# Dowloading event 0: 1994-04-06 19:01:03.350000046
# 14.810497292969876
# Error dowloading event 0: operands could not be broadcast together with shapes (57625,) (7625,)
# Error dowloading event 1: operands could not be broadcast together with shapes (57625,) (7625,)
# Dowloading event 1: 1994-06-16 16:24:26.200000045
# 14.249097081585981
# Error dowloading event 0: operands could not be broadcast together with shapes (11625,) (102625,)
# Error dowloading event 1: operands could not be broadcast together with shapes (11625,) (102625,)
# Dowloading event 2: 1994-11-20 04:31:42.800000171
# 10.296643249800143
# Error dowloading event 0: zero-size array to reduction operation maximum which has no identity
# Error dowloading event 1: zero-size array to reduction operation maximum which has no identity
# Dowloading event 3: 1995-05-07 11:03:32.199999960
# 8.51167171347126
# Error dowloading event 0: operands could not be broadcast together with shapes (91125,) (9000,)
# Error dowloading event 1: operands could not be broadcast together with shapes (91125,) (9000,)
# Dowloading event 4: 1995-09-05 20:27:17.239999959
# 12.586297889492291
# Error dowloading event 0: operands could not be broadcast together with shapes (37100,) (4950,)
# Error dowloading event 1: operands could not be broadcast together with shapes (37100,) (4950,)
# Dowloading event 5: 1996-03-01 09:50:41.999999953
# 13.900597066797971
# Error dowloading event 0: operands could not be broadcast together with shapes (3950,) (4150,)
# Error dowloading event 1: operands could not be broadcast together with shapes (3950,) (4150,)
# Dowloading event 6: 1996-08-14 03:05:26.789999907
# 21.006182559443584
# Error dowloading event 0: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Error dowloading event 1: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 7: 1996-11-27 01:42:42.729999972
# 8.576053199882013
# Error dowloading event 0: operands could not be broadcast together with shapes (22200,) (2600,)
# Error dowloading event 1: operands could not be broadcast together with shapes (22200,) (2600,)
# Dowloading event 8: 1997-03-18 15:24:46.549999895
# 27.670318743429473
# Error dowloading event 0: operands could not be broadcast together with shapes (43200,) (10100,)
# Error dowloading event 1: operands could not be broadcast together with shapes (43200,) (10100,)
# Dowloading event 9: 1997-06-28 21:45:23.420000171
# 15.529958589610477
# Error dowloading event 0: operands could not be broadcast together with shapes (2650,) (18050,)
# Error dowloading event 1: operands could not be broadcast together with shapes (2650,) (18050,)
# Dowloading event 10: 1997-07-26 03:14:55.229999824
# 5.467301434227642
# Error dowloading event 0: operands could not be broadcast together with shapes (29200,) (6400,)
# Error dowloading event 1: operands could not be broadcast together with shapes (29200,) (6400,)
# Dowloading event 11: 1997-07-26 10:24:16.129999909
# 16.471709557358338
# Error dowloading event 0: operands could not be broadcast together with shapes (6300,) (17200,)
# Error dowloading event 1: operands could not be broadcast together with shapes (6300,) (17200,)
# Dowloading event 12: 1997-09-19 22:37:13.709999959
# 11.882893723127967
# Error dowloading event 0: operands could not be broadcast together with shapes (20700,) (7400,)
# Error dowloading event 1: operands could not be broadcast together with shapes (20700,) (7400,)
# Dowloading event 13: 1997-09-28 15:57:22.230000051
# 14.770820731061159
# Error dowloading event 0: operands could not be broadcast together with shapes (20900,) (8100,)
# Error dowloading event 1: operands could not be broadcast together with shapes (20900,) (8100,)
# Dowloading event 14: 1998-03-11 12:18:49.739999927
# 12.543897387956644
# Error dowloading event 0: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Error dowloading event 1: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Dowloading event 15: 1998-07-10 21:29:14.120000024
# 11.870642736226877
# Dowloading event 16: 1998-08-16 13:34:39.349999983
# 11.024899886775602
# Dowloading event 17: 1998-10-01 18:18:13.889999975
# 11.076468840061667
# Dowloading event 18: 1998-10-27 01:08:39.429999908
# 15.162084647297995
# Dowloading event 19: 1999-05-14 07:54:02.619999979
# 10.168366049311153
# Dowloading event 20: 1999-07-19 22:09:25.779999957
# 2.038209868614999
# Dowloading event 21: 1999-09-20 07:02:48.350000074
# 15.60144409727752
# Dowloading event 22: 1999-10-16 09:46:45.000000027
# 20.151501509936626
# Dowloading event 23: 1999-10-16 09:51:50.380000050
# 18.509034974992918
# Dowloading event 24: 1999-10-16 09:59:35.309999993
# 20.939396471946928
# Dowloading event 25: 1999-10-16 10:02:40.919999735
# 19.302060454517086
# Dowloading event 26: 1999-10-16 10:07:35.359999875
# 28.133628409632802
# Dowloading event 27: 1999-10-16 10:09:54.490000011
# 21.372328237915426
# Dowloading event 28: 1999-10-16 10:10:48.879999960
# 21.646792020590976
# Dowloading event 29: 1999-10-16 10:20:51.739999952
# 17.21938977607257
# Dowloading event 30: 1999-10-16 10:29:38.779999995
# 19.77723700370092
# Dowloading event 31: 1999-10-16 11:04:31.999999828
# 17.740854960711776
# Dowloading event 32: 1999-10-16 11:06:37.680000154
# 20.372429061233134
# Dowloading event 33: 1999-10-16 11:26:03.789999790
# 24.442993267621258
# Dowloading event 34: 1999-10-16 11:49:56.949999971
# 23.429634292773166
# Dowloading event 35: 1999-10-16 12:03:18.039999988
# 23.61856016108711
# Dowloading event 36: 1999-10-16 12:57:21.219999837
# 16.499993041412644
# Dowloading event 37: 1999-10-16 13:51:16.679999854
# 18.504201775174163
# Dowloading event 38: 1999-10-16 13:59:16.629999961
# 24.985770210167786
# Dowloading event 39: 1999-10-16 16:08:24.610000070
# 22.050323349138107
# Dowloading event 40: 1999-10-16 17:38:47.270000094
# 17.204421053075986
# Dowloading event 41: 1999-10-16 18:01:56.500000040
# 22.89651265654868
# Dowloading event 42: 1999-10-16 20:13:36.649999781
# 22.77549436950552
# Dowloading event 43: 1999-10-16 21:10:50.009999949
# 22.297107409188648
# Dowloading event 44: 1999-10-16 22:53:39.840000066
# 23.31069007272582
# Dowloading event 45: 1999-10-17 04:22:47.440000084
# 25.443312446058073
# Dowloading event 46: 1999-10-17 16:22:47.540000015
# 17.43042433871542
# Dowloading event 47: 1999-10-17 16:32:51.780000004
# 17.214880601665417
# Dowloading event 48: 1999-10-18 06:35:47.020000188
# 17.129630234683706
# Dowloading event 49: 1999-10-18 11:02:20.249999989
# 25.521792488121086
# Dowloading event 50: 1999-10-19 10:39:40.159999903
# 23.060531226455723
# Dowloading event 51: 1999-10-19 12:20:43.139999970
# 23.545108099847933
# Dowloading event 52: 1999-10-20 16:40:56.030000050
# 22.093306910030996
# Dowloading event 53: 1999-10-21 01:25:41.629999941
# 25.02417642169024
# Dowloading event 54: 1999-10-21 01:54:05.539999919
# 26.02602645510487
# Dowloading event 55: 1999-10-21 01:54:34.399999938
# 23.14893169710195
# Dowloading event 56: 1999-10-21 01:57:40.220000141
# 23.990012857279517
# Dowloading event 57: 1999-10-22 01:58:42.360000015
# 20.840986546071402
# Dowloading event 58: 1999-10-22 16:08:47.129999945
# 24.38683247514826
# Dowloading event 59: 1999-10-22 20:16:00.159999991
# 25.181713736360148
# Dowloading event 60: 1999-10-22 20:17:29.249999995
# 25.60373453313322
# Dowloading event 61: 1999-10-25 18:26:00.340000065
# 20.532741461865502
# Dowloading event 62: 1999-10-29 12:36:37.329999845
# 19.38288158046029
# Dowloading event 63: 1999-10-30 03:32:57.599999983
# 25.534041707120682
# Dowloading event 64: 1999-10-30 11:18:55.950000114
# 23.80270242185963
# Dowloading event 65: 1999-11-14 14:20:08.190000061
# 25.190193024993114
# Dowloading event 66: 1999-12-23 14:30:53.160000030
# 21.86262508154758
# Error dowloading event 0: operands could not be broadcast together with shapes (1331184,) (151300,)
# Error dowloading event 1: operands could not be broadcast together with shapes (1331184,) (151300,)
# Dowloading event 67: 2000-06-12 03:15:00.889999957
# 21.422246679988522
# Dowloading event 68: 2000-06-26 15:43:06.119999952
# 24.131364541045425
# Dowloading event 69: 2000-12-02 08:28:05.979999901
# 13.40659668181236
# Dowloading event 70: 2001-02-10 21:05:04.820000046
# 14.458667191232799
# Dowloading event 71: 2001-02-11 00:39:14.370000001
# 13.79081475661318
# Dowloading event 72: 2001-10-31 07:56:15.590000019
# 1.583325202849015

# %%
np.save(data_dir / "a_max_minus.npy", np.array(a_max_minus))
np.save(data_dir / "a_max_plus.npy", np.array(a_max_plus))

# %%
fig, ax = plt.subplots(2,1, sharex=True, figsize=(4, 6), dpi=150)
ax[0].scatter(np.array(a_max_minus), np.array(a_max_plus), s=0.5)
ax[0].set(
    xscale="log", 
    yscale="log",
    ylabel="Max Amplitude Post-Event",
)

ax[1].scatter(np.array(a_max_minus), np.array(a_max_plus)/np.array(a_max_minus), s=0.5)
ax[1].set(
    xscale="log", 
    yscale="log",
    xlabel="Max Amplitude Pre-Event",
    ylabel="Post / Pre",
)
ax[1].axhline(1, color="k", linestyle="--", lw=0.5)

# %%
# This goes in analysis file

# for each file in REPO 

# load stream

# split into parts

# calculate shaking intensity (e.g. PGV)
