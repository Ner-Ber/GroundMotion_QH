# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.random.normal(10,2,100000)

r = x[:-1]/x[1:]

I = np.argsort(x[1:])

fig, ax = plt.subplots()
ax.scatter(x[1:][I], r[I],s=0.5)
ax.set(yscale='log')
ax.axhline(1,c='k')
